# %%
import os
import random
from openai import OpenAI
import pandas as pd

client = OpenAI(
    api_key='',
    base_url=''
)


def normal_answer(user_content):
  try:
    response0 = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
          {
              "role": "system",
              "content": f"You are a question-and-answer dataset generating expert, you are generating data that will be used to train a large language model designed to address questions posed by users regarding the game Minecraft, and from that, you will generate question-and-answer data samples, each with a prompt/response pair.\n\nYou will do so in this format:\n```\nprompt\n-----------\n$prompt_goes_here\n-----------\n\nresponse\n-----------\n$response_goes_here\n-----------\n```\n\nYour task is to generate at least 20 examples.Make sure your samples are unique and diverse, yet high-quality and complex enough to train a well-performing model."
          },
          {
              "role": "user",
              "content":"Your task is to generate 20 question-and-answer examples. And you will do so in this format:\n```\nprompt\n-----------\n$prompt_goes_here\n-----------\n\nresponse\n-----------\n$response_goes_here\n-----------\n```\n. Please generate as many question and answer pairs as possible. Here are the user content:"+user_content
          }
      ],
      stream=False,
    )
    return response0.choices[0].message.content
  except Exception as e:
    print(f"Error processing file due to: {e}")
    return None
def short_answer(user_content):
  try:
    response1 = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
          {
              "role": "system",
              "content": f"You are a question-and-answer dataset generating expert, you are generating data that will be used to train a large language model designed to address questions posed by users regarding the game Minecraft, and from that, you will generate question-and-answer data samples, each with a prompt/response pair.\n\nYou will do so in this format:\n```\nprompt\n-----------\n$prompt_goes_here\n-----------\n\nresponse\n-----------\n$response_goes_here\n-----------\n```\n\nYour task is to generate at least 30 examples.Make sure your samples are unique and diverse, yet high-quality and complex enough to train a well-performing model."
          },
          {
              "role": "user",
              "content":"Your task is to generate 30 question-and-answer examples, and you should generate questions within the provided user text that can be directly answered with a word or phrase, such as dates, names, statistics, etc. This involves identifying specific, concise information within the text that can be succinctly responded to, ensuring that the answers are clear and directly related to the questions asked. And you will do so in this format:\n```\nprompt\n-----------\n$prompt_goes_here\n-----------\n\nresponse\n-----------\n$response_goes_here\n-----------\n```\n. Please generate as many question and answer pairs as possible. Here are the user content:"+user_content
          }
      ],
      stream=False,
    )
    return response1.choices[0].message.content
  except Exception as e:
    print(f"Error processing file due to: {e}")
    return None
def long_answer(user_content):
  try:
    response2 = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
          {
              "role": "system",
              "content": f"You are a question-and-answer dataset generating expert, you are generating data that will be used to train a large language model designed to address questions posed by users regarding the game Minecraft, and from that, you will generate question-and-answer data samples, each with a prompt/response pair.\n\nYou will do so in this format:\n```\nprompt\n-----------\n$prompt_goes_here\n-----------\n\nresponse\n-----------\n$response_goes_here\n-----------\n```\n\nYour task is to generate at least 20 examples.Make sure your samples are unique and diverse, yet high-quality and complex enough to train a well-performing model."
          },
          {
              "role": "user",
              "content":"Your task is to generate 20 question-and-answer examples. Identify questions within the provided user text that require one or more complete sentences as answers. These questions should be suitable for explanatory or definitional responses, where a detailed explanation or a clear definition is needed to fully address the question. This involves crafting answers that are comprehensive and informative, ensuring they adequately explain or define the subject matter in question. And you will do so in this format:\n```\nprompt\n-----------\n$prompt_goes_here\n-----------\n\nresponse\n-----------\n$response_goes_here\n-----------\n```\n. Please generate as many question and answer pairs as possible. Here are the user content:"+user_content
          }
      ],
      stream=False,
    )
    return response2.choices[0].message.content
  except Exception as e:
    print(f"Error processing file due to: {e}")
    return None
def bool_answer(user_content):
  try:
    response3 = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
          {
              "role": "system",
              "content": f"You are a question-and-answer dataset generating expert, you are generating data that will be used to train a large language model designed to address questions posed by users regarding the game Minecraft, and from that, you will generate question-and-answer data samples, each with a prompt/response pair.\n\nYou will do so in this format:\n```\nprompt\n-----------\n$prompt_goes_here\n-----------\n\nresponse\n-----------\n$response_goes_here\n-----------\n```\n\nYour task is to generate at least 10 examples.Make sure your samples are unique and diverse, yet high-quality and complex enough to train a well-performing model."
          },
          {
              "role": "user",
              "content":"Your task is to generate 10 question-and-answer examples. Look for questions within the provided user text that can be answered with a simple True or False. This task involves pinpointing statements or queries within the text that lend themselves to binary responses, ensuring that the answers are straightforward and unambiguous, clearly indicating whether the statement is true or false based on the information available. And you will do so in this format:\n```\nprompt\n-----------\n$prompt_goes_here\n-----------\n\nresponse\n-----------\n$response_goes_here\n-----------\n```\n. Please generate as many question and answer pairs as possible. Here are the user content:"+user_content
          }
      ],
      stream=False,
    )
    return response3.choices[0].message.content
  except Exception as e:
    print(f"Error processing file due to: {e}")
    return None
def normal_read_md_files(folder_path, start_from=0):
    if not os.path.exists(folder_path):
        print("给定的路径不存在")
        return
    count = 0
    file_number = 0
    csv_number = 1
    save_path = ''
    prompts = []
    responses = []
    md_files = [f for f in os.listdir(folder_path) if f.endswith('.md')]
    md_files.sort()
    for filename in md_files:
        file_number += 1
        if file_number < start_from:
          continue

        file_path = os.path.join(folder_path, filename)

        print(f"正在读取: {file_path}")
        with open(file_path, 'r') as file:
            data = file.read()
        re0 = normal_answer(data)
        if re0 is None:
          print(f"An error in {file_path}")
          count += 1
          continue
        split_example0 = re0.split('-----------')
        length0 = len(split_example0)
        retry=0
        flag=1
        while (length0 < 20 and retry < 3) or flag == 0:
          flag=1
          re0 = normal_answer(data)
          if re0 is None:
            print(f"An error in {file_path}")
            retry += 1
            continue
          split_example0 = re0.split('-----------')
          length0 = len(split_example0)
          retry += 1
          for i in range(1,length0//4+1):
            if 'prompt' in split_example0[4*i-3].strip() or 'response' in split_example0[4*i-3].strip() or 'prompt' in split_example0[4*i-1].strip() or 'response' in split_example0[4*i-1].strip():
              flag = 0
              break
        for i in range(1,length0//4+1):
          prompts.append(split_example0[4*i-3].strip())
          responses.append(split_example0[4*i-1].strip())
        if count % 100 == 99:
          df = pd.DataFrame({
                'prompt': prompts,
                'response': responses
          })
          df = df.drop_duplicates()
          csv_filename = f'normal_crawler_data_{csv_number}.csv'
          df.to_csv(os.path.join(save_path, csv_filename), index=False)
          prompts, responses = [], []
          print(f"已保存 {csv_number} 个数据集。")
          csv_number += 1
        count += 1
        print(f"已读取 {count} 个文件。当前文件编号：{file_number}，路径：{file_path}")

def three_read_md_files(folder_path, start_from=0):
    if not os.path.exists(folder_path):
        print("给定的路径不存在")
        return
    count = 0
    file_number = 0
    csv_number = 1
    save_path = ''
    prompts = []
    responses = []
    md_files = [f for f in os.listdir(folder_path) if f.endswith('.md')]
    md_files.sort()
    for filename in md_files:
        file_number += 1
        if file_number < start_from:
          continue

        file_path = os.path.join(folder_path, filename)

        print(f"正在读取: {file_path}")
        with open(file_path, 'r') as file:
            data = file.read()
        re1 = short_answer(data)
        if re1 is None:
          print(f"An error in {file_path}")
          with open('', 'a') as log_file:  # 'a' 表示追加模式
            log_file.write(filename + '\n')
          count += 1
          continue
        split_example1 = re1.split('-----------')
        length1 = len(split_example1)
        retry=0
        flag=1
        while (length1 < 20 and retry < 3) or flag == 0:
          flag=1
          re1 = short_answer(data)
          if re1 is None:
            print(f"An error in {file_path}")
            retry += 1
            continue
          split_example1 = re1.split('-----------')
          length1 = len(split_example1)
          retry += 1
          for i in range(1,length1//4+1):
            if 'prompt' in split_example1[4*i-3].strip() or 'response' in split_example1[4*i-3].strip() or 'prompt' in split_example1[4*i-1].strip() or 'response' in split_example1[4*i-1].strip():
              flag = 0
              break
        for i in range(1,length1//4+1):
          prompts.append(split_example1[4*i-3].strip())
          responses.append(split_example1[4*i-1].strip())
        re2 = long_answer(data)
        if re2 is None:
          print(f"An error in {file_path}")
          count += 1
          continue
        split_example2 = re2.split('-----------')
        length2 = len(split_example2)
        retry=0
        flag=1
        while (length2 < 20 and retry < 3) or flag == 0:
          flag=1
          re2 = long_answer(data)
          if re2 is None:
            print(f"An error in {file_path}")
            retry += 1
            continue
          split_example2 = re2.split('-----------')
          length2 = len(split_example2)
          retry += 1
          for i in range(1,length2//4+1):
            if 'prompt' in split_example2[4*i-3].strip() or 'response' in split_example2[4*i-3].strip() or 'prompt' in split_example2[4*i-1].strip() or 'response' in split_example2[4*i-1].strip():
              flag = 0
              break
        for i in range(1,length2//4+1):
          prompts.append(split_example2[4*i-3].strip())
          responses.append(split_example2[4*i-1].strip())
        re3 = bool_answer(data)
        if re3 is None:
          print(f"An error in {file_path}")
          count += 1
          continue
        split_example3 = re3.split('-----------')
        length3 = len(split_example3)
        retry=0
        flag=1
        while (length3 < 16 and retry < 3) or flag == 0:
          flag=1
          re3 = bool_answer(data)
          if re3 is None:
            print(f"An error in {file_path}")
            retry += 1
            continue
          split_example3 = re3.split('-----------')
          length3 = len(split_example3)
          retry += 1
          for i in range(1,length3//4+1):
            if 'prompt' in split_example3[4*i-3].strip() or 'response' in split_example3[4*i-3].strip() or 'prompt' in split_example3[4*i-1].strip() or 'response' in split_example3[4*i-1].strip():
              flag = 0
              break
        for i in range(1,length3//4+1):
          prompts.append(split_example3[4*i-3].strip())
          responses.append(split_example3[4*i-1].strip())
        if count % 100 == 99:
          df = pd.DataFrame({
            'prompt': prompts,
            'response': responses
          })
          df = df.drop_duplicates()
          csv_filename = f'three_crawler_data_{csv_number}.csv'
          df.to_csv(os.path.join(save_path, csv_filename), index=False)
          prompts, responses = [], []
          print(f"已保存 {csv_number} 个数据集。")
          csv_number += 1
        count += 1
        print(f"已读取 {count} 个文件。当前文件编号：{file_number}，路径：{file_path}")

folder_path = ''
start_from = 1
normal_read_md_files(folder_path, 1)
three_read_md_files(folder_path, 1)
# Out:
# 正在读取: /content/drive/MyDrive/crawler_data/4/Shelters_15.md
# 已读取 1 个文件。当前文件编号：1，路径：/content/drive/MyDrive/crawler_data/4/Shelters_15.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Shipwreck_0.md
# 已读取 2 个文件。当前文件编号：2，路径：/content/drive/MyDrive/crawler_data/4/Shipwreck_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Shipwreck_1.md
# 已读取 3 个文件。当前文件编号：3，路径：/content/drive/MyDrive/crawler_data/4/Shipwreck_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Shipwreck_2.md
# 已读取 4 个文件。当前文件编号：4，路径：/content/drive/MyDrive/crawler_data/4/Shipwreck_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Shipwrecks_0.md
# 已读取 5 个文件。当前文件编号：5，路径：/content/drive/MyDrive/crawler_data/4/Shipwrecks_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Shipwrecks_1.md
# 已读取 6 个文件。当前文件编号：6，路径：/content/drive/MyDrive/crawler_data/4/Shipwrecks_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Shipwrecks_2.md
# 已读取 7 个文件。当前文件编号：7，路径：/content/drive/MyDrive/crawler_data/4/Shipwrecks_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Short_grass_0.md
# 已读取 8 个文件。当前文件编号：8，路径：/content/drive/MyDrive/crawler_data/4/Short_grass_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Short_grass_1.md
# 已读取 9 个文件。当前文件编号：9，路径：/content/drive/MyDrive/crawler_data/4/Short_grass_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Shrubland_0.md
# 已读取 10 个文件。当前文件编号：10，路径：/content/drive/MyDrive/crawler_data/4/Shrubland_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Shulker_0.md
# 已读取 11 个文件。当前文件编号：11，路径：/content/drive/MyDrive/crawler_data/4/Shulker_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Shulker_1.md
# 已读取 12 个文件。当前文件编号：12，路径：/content/drive/MyDrive/crawler_data/4/Shulker_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Shulker_box_storage_0.md
# 已读取 13 个文件。当前文件编号：13，路径：/content/drive/MyDrive/crawler_data/4/Shulker_box_storage_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Shulker_farming_0.md
# 已读取 14 个文件。当前文件编号：14，路径：/content/drive/MyDrive/crawler_data/4/Shulker_farming_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Shulker_farming_1.md
# 已读取 15 个文件。当前文件编号：15，路径：/content/drive/MyDrive/crawler_data/4/Shulker_farming_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Silence_Armor_Trim_0.md
# 已读取 16 个文件。当前文件编号：16，路径：/content/drive/MyDrive/crawler_data/4/Silence_Armor_Trim_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Silence_Armor_Trim_Smithing_Template_0.md
# 已读取 17 个文件。当前文件编号：17，路径：/content/drive/MyDrive/crawler_data/4/Silence_Armor_Trim_Smithing_Template_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Simple_block_0.md
# 已读取 18 个文件。当前文件编号：18，路径：/content/drive/MyDrive/crawler_data/4/Simple_block_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Simple_random_selector_0.md
# 已读取 19 个文件。当前文件编号：19，路径：/content/drive/MyDrive/crawler_data/4/Simple_random_selector_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Single_Biome_0.md
# 已读取 20 个文件。当前文件编号：20，路径：/content/drive/MyDrive/crawler_data/4/Single_Biome_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sitting_0.md
# 已读取 21 个文件。当前文件编号：21，路径：/content/drive/MyDrive/crawler_data/4/Sitting_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Skeleton_0.md
# 已读取 22 个文件。当前文件编号：22，路径：/content/drive/MyDrive/crawler_data/4/Skeleton_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Skeleton_1.md
# 已读取 23 个文件。当前文件编号：23，路径：/content/drive/MyDrive/crawler_data/4/Skeleton_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Skeleton_2.md
# 已读取 24 个文件。当前文件编号：24，路径：/content/drive/MyDrive/crawler_data/4/Skeleton_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Skin_0.md
# 已读取 25 个文件。当前文件编号：25，路径：/content/drive/MyDrive/crawler_data/4/Skin_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Skin_1.md
# 已读取 26 个文件。当前文件编号：26，路径：/content/drive/MyDrive/crawler_data/4/Skin_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Skin_pack_0.md
# 已读取 27 个文件。当前文件编号：27，路径：/content/drive/MyDrive/crawler_data/4/Skin_pack_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Skin_pack_1.md
# 已读取 28 个文件。当前文件编号：28，路径：/content/drive/MyDrive/crawler_data/4/Skin_pack_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Skin_pack_2.md
# 已读取 29 个文件。当前文件编号：29，路径：/content/drive/MyDrive/crawler_data/4/Skin_pack_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Skin_pack_3.md
# 已读取 30 个文件。当前文件编号：30，路径：/content/drive/MyDrive/crawler_data/4/Skin_pack_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Skin_pack_4.md
# 已读取 31 个文件。当前文件编号：31，路径：/content/drive/MyDrive/crawler_data/4/Skin_pack_4.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/SkyWars_0.md
# 已读取 32 个文件。当前文件编号：32，路径：/content/drive/MyDrive/crawler_data/4/SkyWars_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sky_0.md
# 已读取 33 个文件。当前文件编号：33，路径：/content/drive/MyDrive/crawler_data/4/Sky_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sky_Dimension_0.md
# 已读取 34 个文件。当前文件编号：34，路径：/content/drive/MyDrive/crawler_data/4/Sky_Dimension_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Skyblock_0.md
# 已读取 35 个文件。当前文件编号：35，路径：/content/drive/MyDrive/crawler_data/4/Skyblock_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Skyblock_1.md
# 已读取 36 个文件。当前文件编号：36，路径：/content/drive/MyDrive/crawler_data/4/Skyblock_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Skyblock_2.md
# 已读取 37 个文件。当前文件编号：37，路径：/content/drive/MyDrive/crawler_data/4/Skyblock_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Slime_0.md
# 已读取 38 个文件。当前文件编号：38，路径：/content/drive/MyDrive/crawler_data/4/Slime_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Slime_1.md
# 已读取 39 个文件。当前文件编号：39，路径：/content/drive/MyDrive/crawler_data/4/Slime_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Slime_farming_0.md
# 已读取 40 个文件。当前文件编号：40，路径：/content/drive/MyDrive/crawler_data/4/Slime_farming_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Slime_farming_1.md
# 已读取 41 个文件。当前文件编号：41，路径：/content/drive/MyDrive/crawler_data/4/Slime_farming_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Small_End_Islands_0.md
# 已读取 42 个文件。当前文件编号：42，路径：/content/drive/MyDrive/crawler_data/4/Small_End_Islands_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Small_End_Islands_1.md
# 已读取 43 个文件。当前文件编号：43，路径：/content/drive/MyDrive/crawler_data/4/Small_End_Islands_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Small_End_Islands_2.md
# 已读取 44 个文件。当前文件编号：44，路径：/content/drive/MyDrive/crawler_data/4/Small_End_Islands_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Small_island_0.md
# 已读取 45 个文件。当前文件编号：45，路径：/content/drive/MyDrive/crawler_data/4/Small_island_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Smelting_0.md
# 已读取 46 个文件。当前文件编号：46，路径：/content/drive/MyDrive/crawler_data/4/Smelting_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Smelting_1.md
# 已读取 47 个文件。当前文件编号：47，路径：/content/drive/MyDrive/crawler_data/4/Smelting_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Smelting_2.md
# 已读取 48 个文件。当前文件编号：48，路径：/content/drive/MyDrive/crawler_data/4/Smelting_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Smelting_3.md
# 已读取 49 个文件。当前文件编号：49，路径：/content/drive/MyDrive/crawler_data/4/Smelting_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Smithing_0.md
# 已读取 50 个文件。当前文件编号：50，路径：/content/drive/MyDrive/crawler_data/4/Smithing_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Smithing_Table_0.md
# 已读取 51 个文件。当前文件编号：51，路径：/content/drive/MyDrive/crawler_data/4/Smithing_Table_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Smithing_Template_0.md
# 已读取 52 个文件。当前文件编号：52，路径：/content/drive/MyDrive/crawler_data/4/Smithing_Template_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Smithing_Template_1.md
# 已读取 53 个文件。当前文件编号：53，路径：/content/drive/MyDrive/crawler_data/4/Smithing_Template_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Smooth_basalt_0.md
# 已读取 54 个文件。当前文件编号：54，路径：/content/drive/MyDrive/crawler_data/4/Smooth_basalt_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sneaking_0.md
# 已读取 55 个文件。当前文件编号：55，路径：/content/drive/MyDrive/crawler_data/4/Sneaking_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sniffer_Egg_0.md
# 已读取 56 个文件。当前文件编号：56，路径：/content/drive/MyDrive/crawler_data/4/Sniffer_Egg_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snout_Armor_Trim_0.md
# 已读取 57 个文件。当前文件编号：57，路径：/content/drive/MyDrive/crawler_data/4/Snout_Armor_Trim_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snout_Armor_Trim_Smithing_Template_0.md
# 已读取 58 个文件。当前文件编号：58，路径：/content/drive/MyDrive/crawler_data/4/Snout_Armor_Trim_Smithing_Template_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snow_0.md
# 已读取 59 个文件。当前文件编号：59，路径：/content/drive/MyDrive/crawler_data/4/Snow_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snow_1.md
# 已读取 60 个文件。当前文件编号：60，路径：/content/drive/MyDrive/crawler_data/4/Snow_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snow_block_0.md
# 已读取 61 个文件。当前文件编号：61，路径：/content/drive/MyDrive/crawler_data/4/Snow_block_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snow_capped_peaks_0.md
# 已读取 62 个文件。当前文件编号：62，路径：/content/drive/MyDrive/crawler_data/4/Snow_capped_peaks_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snow_capped_peaks_1.md
# 已读取 63 个文件。当前文件编号：63，路径：/content/drive/MyDrive/crawler_data/4/Snow_capped_peaks_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snow_capped_peaks_2.md
# 已读取 64 个文件。当前文件编号：64，路径：/content/drive/MyDrive/crawler_data/4/Snow_capped_peaks_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snow_capped_peaks_3.md
# 已读取 65 个文件。当前文件编号：65，路径：/content/drive/MyDrive/crawler_data/4/Snow_capped_peaks_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snow_farming_0.md
# 已读取 66 个文件。当前文件编号：66，路径：/content/drive/MyDrive/crawler_data/4/Snow_farming_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snow_farming_1.md
# 已读取 67 个文件。当前文件编号：67，路径：/content/drive/MyDrive/crawler_data/4/Snow_farming_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snow_golems_0.md
# 已读取 68 个文件。当前文件编号：68，路径：/content/drive/MyDrive/crawler_data/4/Snow_golems_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snow_golems_1.md
# 已读取 69 个文件。当前文件编号：69，路径：/content/drive/MyDrive/crawler_data/4/Snow_golems_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowcapped_peaks_0.md
# 已读取 70 个文件。当前文件编号：70，路径：/content/drive/MyDrive/crawler_data/4/Snowcapped_peaks_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowcapped_peaks_1.md
# 已读取 71 个文件。当前文件编号：71，路径：/content/drive/MyDrive/crawler_data/4/Snowcapped_peaks_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowcapped_peaks_2.md
# 已读取 72 个文件。当前文件编号：72，路径：/content/drive/MyDrive/crawler_data/4/Snowcapped_peaks_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowcapped_peaks_3.md
# 已读取 73 个文件。当前文件编号：73，路径：/content/drive/MyDrive/crawler_data/4/Snowcapped_peaks_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowfall_0.md
# 已读取 74 个文件。当前文件编号：74，路径：/content/drive/MyDrive/crawler_data/4/Snowfall_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowlogging_0.md
# 已读取 75 个文件。当前文件编号：75，路径：/content/drive/MyDrive/crawler_data/4/Snowlogging_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Beach_0.md
# 已读取 76 个文件。当前文件编号：76，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Beach_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Beach_1.md
# 已读取 77 个文件。当前文件编号：77，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Beach_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Beach_2.md
# 已读取 78 个文件。当前文件编号：78，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Beach_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Mountains_0.md
# 已读取 79 个文件。当前文件编号：79，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Mountains_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Mountains_1.md
# 已读取 80 个文件。当前文件编号：80，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Mountains_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Mountains_10.md
# 已读取 81 个文件。当前文件编号：81，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Mountains_10.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Mountains_11.md
# 已读取 82 个文件。当前文件编号：82，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Mountains_11.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Mountains_12.md
# 已读取 83 个文件。当前文件编号：83，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Mountains_12.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Mountains_13.md
# 已读取 84 个文件。当前文件编号：84，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Mountains_13.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Mountains_14.md
# 已读取 85 个文件。当前文件编号：85，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Mountains_14.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Mountains_15.md
# 已读取 86 个文件。当前文件编号：86，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Mountains_15.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Mountains_16.md
# 已读取 87 个文件。当前文件编号：87，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Mountains_16.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Mountains_17.md
# 已读取 88 个文件。当前文件编号：88，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Mountains_17.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Mountains_18.md
# 已读取 89 个文件。当前文件编号：89，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Mountains_18.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Mountains_2.md
# 已读取 90 个文件。当前文件编号：90，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Mountains_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Mountains_3.md
# 已读取 91 个文件。当前文件编号：91，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Mountains_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Mountains_4.md
# 已读取 92 个文件。当前文件编号：92，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Mountains_4.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Mountains_5.md
# 已读取 93 个文件。当前文件编号：93，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Mountains_5.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Mountains_6.md
# 已读取 94 个文件。当前文件编号：94，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Mountains_6.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Mountains_7.md
# 已读取 95 个文件。当前文件编号：95，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Mountains_7.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Mountains_8.md
# 已读取 96 个文件。当前文件编号：96，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Mountains_8.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Mountains_9.md
# 已读取 97 个文件。当前文件编号：97，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Mountains_9.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Slopes_0.md
# 已读取 98 个文件。当前文件编号：98，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Slopes_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Slopes_1.md
# 已读取 99 个文件。当前文件编号：99，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Slopes_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Slopes_2.md
# 已保存 1 个数据集。
# 已读取 100 个文件。当前文件编号：100，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Slopes_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Slopes_3.md
# 已读取 101 个文件。当前文件编号：101，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Slopes_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_0.md
# 已读取 102 个文件。当前文件编号：102，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_1.md
# 已读取 103 个文件。当前文件编号：103，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_10.md
# 已读取 104 个文件。当前文件编号：104，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_10.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_11.md
# 已读取 105 个文件。当前文件编号：105，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_11.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_12.md
# 已读取 106 个文件。当前文件编号：106，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_12.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_13.md
# 已读取 107 个文件。当前文件编号：107，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_13.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_14.md
# 已读取 108 个文件。当前文件编号：108，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_14.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_15.md
# 已读取 109 个文件。当前文件编号：109，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_15.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_16.md
# 已读取 110 个文件。当前文件编号：110，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_16.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_17.md
# 已读取 111 个文件。当前文件编号：111，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_17.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_18.md
# 已读取 112 个文件。当前文件编号：112，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_18.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_2.md
# 已读取 113 个文件。当前文件编号：113，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_3.md
# 已读取 114 个文件。当前文件编号：114，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_4.md
# 已读取 115 个文件。当前文件编号：115，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_4.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_5.md
# 已读取 116 个文件。当前文件编号：116，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_5.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_6.md
# 已读取 117 个文件。当前文件编号：117，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_6.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_7.md
# 已读取 118 个文件。当前文件编号：118，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_7.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_8.md
# 已读取 119 个文件。当前文件编号：119，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_8.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_9.md
# 已读取 120 个文件。当前文件编号：120，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Hills_9.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_0.md
# 已读取 121 个文件。当前文件编号：121，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_1.md
# 已读取 122 个文件。当前文件编号：122，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_10.md
# 已读取 123 个文件。当前文件编号：123，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_10.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_11.md
# 已读取 124 个文件。当前文件编号：124，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_11.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_12.md
# Error processing file due to: Error code: 403 - {'detail': 'chat-requirements error'}
# An error in /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_12.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_13.md
# 已读取 126 个文件。当前文件编号：126，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_13.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_14.md
# 已读取 127 个文件。当前文件编号：127，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_14.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_15.md
# 已读取 128 个文件。当前文件编号：128，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_15.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_16.md
# 已读取 129 个文件。当前文件编号：129，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_16.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_17.md
# 已读取 130 个文件。当前文件编号：130，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_17.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_18.md
# 已读取 131 个文件。当前文件编号：131，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_18.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_2.md
# 已读取 132 个文件。当前文件编号：132，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_3.md
# 已读取 133 个文件。当前文件编号：133，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_4.md
# 已读取 134 个文件。当前文件编号：134，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_4.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_5.md
# 已读取 135 个文件。当前文件编号：135，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_5.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_6.md
# 已读取 136 个文件。当前文件编号：136，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_6.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_7.md
# 已读取 137 个文件。当前文件编号：137，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_7.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_8.md
# 已读取 138 个文件。当前文件编号：138，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_8.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_9.md
# 已读取 139 个文件。当前文件编号：139，路径：/content/drive/MyDrive/crawler_data/4/Snowy_Taiga_Mountains_9.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_plains_0.md
# 已读取 140 个文件。当前文件编号：140，路径：/content/drive/MyDrive/crawler_data/4/Snowy_plains_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_plains_1.md
# 已读取 141 个文件。当前文件编号：141，路径：/content/drive/MyDrive/crawler_data/4/Snowy_plains_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_plains_2.md
# 已读取 142 个文件。当前文件编号：142，路径：/content/drive/MyDrive/crawler_data/4/Snowy_plains_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_taiga_0.md
# 已读取 143 个文件。当前文件编号：143，路径：/content/drive/MyDrive/crawler_data/4/Snowy_taiga_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_taiga_1.md
# 已读取 144 个文件。当前文件编号：144，路径：/content/drive/MyDrive/crawler_data/4/Snowy_taiga_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_tundra_0.md
# 已读取 145 个文件。当前文件编号：145，路径：/content/drive/MyDrive/crawler_data/4/Snowy_tundra_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_tundra_1.md
# 已读取 146 个文件。当前文件编号：146，路径：/content/drive/MyDrive/crawler_data/4/Snowy_tundra_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Snowy_tundra_2.md
# 已读取 147 个文件。当前文件编号：147，路径：/content/drive/MyDrive/crawler_data/4/Snowy_tundra_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Solid_block_0.md
# 已读取 148 个文件。当前文件编号：148，路径：/content/drive/MyDrive/crawler_data/4/Solid_block_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Solid_block_1.md
# 已读取 149 个文件。当前文件编号：149，路径：/content/drive/MyDrive/crawler_data/4/Solid_block_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Soul_Sand_Valley_0.md
# 已读取 150 个文件。当前文件编号：150，路径：/content/drive/MyDrive/crawler_data/4/Soul_Sand_Valley_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Soul_Soil_farming_0.md
# 已读取 151 个文件。当前文件编号：151，路径：/content/drive/MyDrive/crawler_data/4/Soul_Soil_farming_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Soul_Speed_0.md
# 已读取 152 个文件。当前文件编号：152，路径：/content/drive/MyDrive/crawler_data/4/Soul_Speed_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Soul_fire_0.md
# 已读取 153 个文件。当前文件编号：153，路径：/content/drive/MyDrive/crawler_data/4/Soul_fire_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Soul_sand_0.md
# 已读取 154 个文件。当前文件编号：154，路径：/content/drive/MyDrive/crawler_data/4/Soul_sand_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Soul_sand_1.md
# 已读取 155 个文件。当前文件编号：155，路径：/content/drive/MyDrive/crawler_data/4/Soul_sand_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Soul_soil_0.md
# 已读取 156 个文件。当前文件编号：156，路径：/content/drive/MyDrive/crawler_data/4/Soul_soil_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sound_directory_0.md
# 已读取 157 个文件。当前文件编号：157，路径：/content/drive/MyDrive/crawler_data/4/Sound_directory_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sound_directory_1.md
# 已读取 158 个文件。当前文件编号：158，路径：/content/drive/MyDrive/crawler_data/4/Sound_directory_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sound_directory_2.md
# 已读取 159 个文件。当前文件编号：159，路径：/content/drive/MyDrive/crawler_data/4/Sound_directory_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/South-east_rule_0.md
# 已读取 160 个文件。当前文件编号：160，路径：/content/drive/MyDrive/crawler_data/4/South-east_rule_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sparse_Jungle_0.md
# 已读取 161 个文件。当前文件编号：161，路径：/content/drive/MyDrive/crawler_data/4/Sparse_Jungle_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sparse_Jungle_1.md
# 已读取 162 个文件。当前文件编号：162，路径：/content/drive/MyDrive/crawler_data/4/Sparse_Jungle_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sparse_Jungle_2.md
# 已读取 163 个文件。当前文件编号：163，路径：/content/drive/MyDrive/crawler_data/4/Sparse_Jungle_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sparse_Jungle_3.md
# 已读取 164 个文件。当前文件编号：164，路径：/content/drive/MyDrive/crawler_data/4/Sparse_Jungle_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Spawn-proofing_0.md
# 已读取 165 个文件。当前文件编号：165，路径：/content/drive/MyDrive/crawler_data/4/Spawn-proofing_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Spawn_0.md
# 已读取 166 个文件。当前文件编号：166，路径：/content/drive/MyDrive/crawler_data/4/Spawn_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Spawn_1.md
# 已读取 167 个文件。当前文件编号：167，路径：/content/drive/MyDrive/crawler_data/4/Spawn_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Spawn_2.md
# 已读取 168 个文件。当前文件编号：168，路径：/content/drive/MyDrive/crawler_data/4/Spawn_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Spawn_3.md
# 已读取 169 个文件。当前文件编号：169，路径：/content/drive/MyDrive/crawler_data/4/Spawn_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Spawn_4.md
# 已读取 170 个文件。当前文件编号：170，路径：/content/drive/MyDrive/crawler_data/4/Spawn_4.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Spawn_5.md
# 已读取 171 个文件。当前文件编号：171，路径：/content/drive/MyDrive/crawler_data/4/Spawn_5.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Spawn_6.md
# 已读取 172 个文件。当前文件编号：172，路径：/content/drive/MyDrive/crawler_data/4/Spawn_6.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Spawn_egg_0.md
# 已读取 173 个文件。当前文件编号：173，路径：/content/drive/MyDrive/crawler_data/4/Spawn_egg_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Spawn_egg_1.md
# 已读取 174 个文件。当前文件编号：174，路径：/content/drive/MyDrive/crawler_data/4/Spawn_egg_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Spawn_egg_2.md
# 已读取 175 个文件。当前文件编号：175，路径：/content/drive/MyDrive/crawler_data/4/Spawn_egg_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Spawn_jail_0.md
# 已读取 176 个文件。当前文件编号：176，路径：/content/drive/MyDrive/crawler_data/4/Spawn_jail_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Spawn_protection_0.md
# 已读取 177 个文件。当前文件编号：177，路径：/content/drive/MyDrive/crawler_data/4/Spawn_protection_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Speedrun_0.md
# 已读取 178 个文件。当前文件编号：178，路径：/content/drive/MyDrive/crawler_data/4/Speedrun_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Speedrun_1.md
# 已读取 179 个文件。当前文件编号：179，路径：/content/drive/MyDrive/crawler_data/4/Speedrun_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Speedrun_2.md
# 已读取 180 个文件。当前文件编号：180，路径：/content/drive/MyDrive/crawler_data/4/Speedrun_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Speedrun_3.md
# 已读取 181 个文件。当前文件编号：181，路径：/content/drive/MyDrive/crawler_data/4/Speedrun_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Speedrun_4.md
# 已读取 182 个文件。当前文件编号：182，路径：/content/drive/MyDrive/crawler_data/4/Speedrun_4.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Speedrun_5.md
# 已读取 183 个文件。当前文件编号：183，路径：/content/drive/MyDrive/crawler_data/4/Speedrun_5.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Speedrun_6.md
# 已读取 184 个文件。当前文件编号：184，路径：/content/drive/MyDrive/crawler_data/4/Speedrun_6.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Speedrun_7.md
# 已读取 185 个文件。当前文件编号：185，路径：/content/drive/MyDrive/crawler_data/4/Speedrun_7.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Spider_0.md
# 已读取 186 个文件。当前文件编号：186，路径：/content/drive/MyDrive/crawler_data/4/Spider_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Spire_Armor_Trim_0.md
# 已读取 187 个文件。当前文件编号：187，路径：/content/drive/MyDrive/crawler_data/4/Spire_Armor_Trim_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Spire_Armor_Trim_Smithing_Template_0.md
# 已读取 188 个文件。当前文件编号：188，路径：/content/drive/MyDrive/crawler_data/4/Spire_Armor_Trim_Smithing_Template_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Splash_0.md
# Error processing file due to: Error code: 429 - {'error': {'message': '当前分组上游负载已饱和，请稍后再试 (request id: 2024042218265023019414718144243)', 'type': 'tokens', 'param': '', 'code': 'rate_limit_exceeded'}}
# An error in /content/drive/MyDrive/crawler_data/4/Splash_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Splash_1.md
# 已读取 190 个文件。当前文件编号：190，路径：/content/drive/MyDrive/crawler_data/4/Splash_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Splash_2.md
# 已读取 191 个文件。当前文件编号：191，路径：/content/drive/MyDrive/crawler_data/4/Splash_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Splash_3.md
# 已读取 192 个文件。当前文件编号：192，路径：/content/drive/MyDrive/crawler_data/4/Splash_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Splash_potion_0.md
# 已读取 193 个文件。当前文件编号：193，路径：/content/drive/MyDrive/crawler_data/4/Splash_potion_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Splash_potion_1.md
# 已读取 194 个文件。当前文件编号：194，路径：/content/drive/MyDrive/crawler_data/4/Splash_potion_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sponge_0.md
# 已读取 195 个文件。当前文件编号：195，路径：/content/drive/MyDrive/crawler_data/4/Sponge_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Spore_blossom_0.md
# 已读取 196 个文件。当前文件编号：196，路径：/content/drive/MyDrive/crawler_data/4/Spore_blossom_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Spring_0.md
# 已读取 197 个文件。当前文件编号：197，路径：/content/drive/MyDrive/crawler_data/4/Spring_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sprinting_0.md
# 已读取 198 个文件。当前文件编号：198，路径：/content/drive/MyDrive/crawler_data/4/Sprinting_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Spruce_0.md
# 已读取 199 个文件。当前文件编号：199，路径：/content/drive/MyDrive/crawler_data/4/Spruce_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Spruce_tree_0.md
# 已保存 2 个数据集。
# 已读取 200 个文件。当前文件编号：200，路径：/content/drive/MyDrive/crawler_data/4/Spruce_tree_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Squid_0.md
# 已读取 201 个文件。当前文件编号：201，路径：/content/drive/MyDrive/crawler_data/4/Squid_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Squid_farming_0.md
# 已读取 202 个文件。当前文件编号：202，路径：/content/drive/MyDrive/crawler_data/4/Squid_farming_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Stained_glass_0.md
# 已读取 203 个文件。当前文件编号：203，路径：/content/drive/MyDrive/crawler_data/4/Stained_glass_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Stained_glass_pane_0.md
# 已读取 204 个文件。当前文件编号：204，路径：/content/drive/MyDrive/crawler_data/4/Stained_glass_pane_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Stained_glass_pane_1.md
# 已读取 205 个文件。当前文件编号：205，路径：/content/drive/MyDrive/crawler_data/4/Stained_glass_pane_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Stained_terracotta_0.md
# 已读取 206 个文件。当前文件编号：206，路径：/content/drive/MyDrive/crawler_data/4/Stained_terracotta_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Star_0.md
# Error processing file due to: Error code: 400 - {'error': {'message': "This model's maximum context length is 16385 tokens. However, your messages resulted in 26147 tokens. Please reduce the length of the messages. (request id: 20240422184107608027172NDVpfsgk) (request id: 2024042218373047392140460885862) (request id: 2024042218373041561665946392438)", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# An error in /content/drive/MyDrive/crawler_data/4/Star_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Starting_house_0.md
# 已读取 208 个文件。当前文件编号：208，路径：/content/drive/MyDrive/crawler_data/4/Starting_house_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Stone_0.md
# 已读取 209 个文件。当前文件编号：209，路径：/content/drive/MyDrive/crawler_data/4/Stone_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Stone_bricks_0.md
# 已读取 210 个文件。当前文件编号：210，路径：/content/drive/MyDrive/crawler_data/4/Stone_bricks_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Stony_Peaks_0.md
# 已读取 211 个文件。当前文件编号：211，路径：/content/drive/MyDrive/crawler_data/4/Stony_Peaks_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Stony_Peaks_1.md
# 已读取 212 个文件。当前文件编号：212，路径：/content/drive/MyDrive/crawler_data/4/Stony_Peaks_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Stony_Peaks_2.md
# 已读取 213 个文件。当前文件编号：213，路径：/content/drive/MyDrive/crawler_data/4/Stony_Peaks_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Stony_Peaks_3.md
# 已读取 214 个文件。当前文件编号：214，路径：/content/drive/MyDrive/crawler_data/4/Stony_Peaks_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Stony_Shore_0.md
# 已读取 215 个文件。当前文件编号：215，路径：/content/drive/MyDrive/crawler_data/4/Stony_Shore_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Stony_Shore_1.md
# 已读取 216 个文件。当前文件编号：216，路径：/content/drive/MyDrive/crawler_data/4/Stony_Shore_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Stony_Shore_2.md
# 已读取 217 个文件。当前文件编号：217，路径：/content/drive/MyDrive/crawler_data/4/Stony_Shore_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Storage_minecarts_0.md
# 已读取 218 个文件。当前文件编号：218，路径：/content/drive/MyDrive/crawler_data/4/Storage_minecarts_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Storage_minecarts_1.md
# 已读取 219 个文件。当前文件编号：219，路径：/content/drive/MyDrive/crawler_data/4/Storage_minecarts_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Stray_0.md
# 已读取 220 个文件。当前文件编号：220，路径：/content/drive/MyDrive/crawler_data/4/Stray_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Strider_0.md
# 已读取 221 个文件。当前文件编号：221，路径：/content/drive/MyDrive/crawler_data/4/Strider_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Strider_1.md
# 已读取 222 个文件。当前文件编号：222，路径：/content/drive/MyDrive/crawler_data/4/Strider_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Strip_0.md
# 已读取 223 个文件。当前文件编号：223，路径：/content/drive/MyDrive/crawler_data/4/Strip_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Strip_1.md
# 已读取 224 个文件。当前文件编号：224，路径：/content/drive/MyDrive/crawler_data/4/Strip_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Stronghold_0.md
# 已读取 225 个文件。当前文件编号：225，路径：/content/drive/MyDrive/crawler_data/4/Stronghold_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Stronghold_1.md
# 已读取 226 个文件。当前文件编号：226，路径：/content/drive/MyDrive/crawler_data/4/Stronghold_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Stronghold_2.md
# 已读取 227 个文件。当前文件编号：227，路径：/content/drive/MyDrive/crawler_data/4/Stronghold_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Structure_(old)_0.md
# 已读取 228 个文件。当前文件编号：228，路径：/content/drive/MyDrive/crawler_data/4/Structure_(old)_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Structure_0.md
# 已读取 229 个文件。当前文件编号：229，路径：/content/drive/MyDrive/crawler_data/4/Structure_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Structure_1.md
# 已读取 230 个文件。当前文件编号：230，路径：/content/drive/MyDrive/crawler_data/4/Structure_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Structure_2.md
# 已读取 231 个文件。当前文件编号：231，路径：/content/drive/MyDrive/crawler_data/4/Structure_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Structure_Block_0.md
# 已读取 232 个文件。当前文件编号：232，路径：/content/drive/MyDrive/crawler_data/4/Structure_Block_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Structure_Block_1.md
# 已读取 233 个文件。当前文件编号：233，路径：/content/drive/MyDrive/crawler_data/4/Structure_Block_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Structure_Block_2.md
# 已读取 234 个文件。当前文件编号：234，路径：/content/drive/MyDrive/crawler_data/4/Structure_Block_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sugar_Cane_farming_0.md
# 已读取 235 个文件。当前文件编号：235，路径：/content/drive/MyDrive/crawler_data/4/Sugar_Cane_farming_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sugar_Cane_farming_1.md
# 已读取 236 个文件。当前文件编号：236，路径：/content/drive/MyDrive/crawler_data/4/Sugar_Cane_farming_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sugar_cane_0.md
# 已读取 237 个文件。当前文件编号：237，路径：/content/drive/MyDrive/crawler_data/4/Sugar_cane_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sugar_cane_1.md
# 已读取 238 个文件。当前文件编号：238，路径：/content/drive/MyDrive/crawler_data/4/Sugar_cane_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Summoning_jockeys_0.md
# 已读取 239 个文件。当前文件编号：239，路径：/content/drive/MyDrive/crawler_data/4/Summoning_jockeys_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Summoning_jockeys_1.md
# 已读取 240 个文件。当前文件编号：240，路径：/content/drive/MyDrive/crawler_data/4/Summoning_jockeys_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sun_0.md
# 已读取 241 个文件。当前文件编号：241，路径：/content/drive/MyDrive/crawler_data/4/Sun_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sunflower_0.md
# 已读取 242 个文件。当前文件编号：242，路径：/content/drive/MyDrive/crawler_data/4/Sunflower_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sunflower_plains_0.md
# 已读取 243 个文件。当前文件编号：243，路径：/content/drive/MyDrive/crawler_data/4/Sunflower_plains_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sunflower_plains_1.md
# 已读取 244 个文件。当前文件编号：244，路径：/content/drive/MyDrive/crawler_data/4/Sunflower_plains_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Superflat_0.md
# 已读取 245 个文件。当前文件编号：245，路径：/content/drive/MyDrive/crawler_data/4/Superflat_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Superflat_1.md
# 已读取 246 个文件。当前文件编号：246，路径：/content/drive/MyDrive/crawler_data/4/Superflat_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Superflat_survival_0.md
# 已读取 247 个文件。当前文件编号：247，路径：/content/drive/MyDrive/crawler_data/4/Superflat_survival_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Superflat_survival_1.md
# 已读取 248 个文件。当前文件编号：248，路径：/content/drive/MyDrive/crawler_data/4/Superflat_survival_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Superflat_survival_2.md
# 已读取 249 个文件。当前文件编号：249，路径：/content/drive/MyDrive/crawler_data/4/Superflat_survival_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Superflat_survival_3.md
# 已读取 250 个文件。当前文件编号：250，路径：/content/drive/MyDrive/crawler_data/4/Superflat_survival_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_0.md
# 已读取 251 个文件。当前文件编号：251，路径：/content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_1.md
# 已读取 252 个文件。当前文件编号：252，路径：/content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_10.md
# 已读取 253 个文件。当前文件编号：253，路径：/content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_10.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_11.md
# 已读取 254 个文件。当前文件编号：254，路径：/content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_11.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_12.md
# 已读取 255 个文件。当前文件编号：255，路径：/content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_12.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_13.md
# 已读取 256 个文件。当前文件编号：256，路径：/content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_13.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_14.md
# 已读取 257 个文件。当前文件编号：257，路径：/content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_14.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_2.md
# 已读取 258 个文件。当前文件编号：258，路径：/content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_3.md
# 已读取 259 个文件。当前文件编号：259，路径：/content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_4.md
# 已读取 260 个文件。当前文件编号：260，路径：/content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_4.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_5.md
# 已读取 261 个文件。当前文件编号：261，路径：/content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_5.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_6.md
# 已读取 262 个文件。当前文件编号：262，路径：/content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_6.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_7.md
# 已读取 263 个文件。当前文件编号：263，路径：/content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_7.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_8.md
# 已读取 264 个文件。当前文件编号：264，路径：/content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_8.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_9.md
# 已读取 265 个文件。当前文件编号：265，路径：/content/drive/MyDrive/crawler_data/4/Survival_in_an_infinite_desert_9.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Survival_with_no_enabled_data_packs_0.md
# 已读取 266 个文件。当前文件编号：266，路径：/content/drive/MyDrive/crawler_data/4/Survival_with_no_enabled_data_packs_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Survival_with_no_enabled_data_packs_1.md
# 已读取 267 个文件。当前文件编号：267，路径：/content/drive/MyDrive/crawler_data/4/Survival_with_no_enabled_data_packs_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Surviving_in_a_single_area_indefinitely_0.md
# 已读取 268 个文件。当前文件编号：268，路径：/content/drive/MyDrive/crawler_data/4/Surviving_in_a_single_area_indefinitely_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Suspicious_gravel_0.md
# 已读取 269 个文件。当前文件编号：269，路径：/content/drive/MyDrive/crawler_data/4/Suspicious_gravel_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Suspicious_gravel_1.md
# 已读取 270 个文件。当前文件编号：270，路径：/content/drive/MyDrive/crawler_data/4/Suspicious_gravel_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Suspicious_sand_0.md
# 已读取 271 个文件。当前文件编号：271，路径：/content/drive/MyDrive/crawler_data/4/Suspicious_sand_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Suspicious_sand_1.md
# 已读取 272 个文件。当前文件编号：272，路径：/content/drive/MyDrive/crawler_data/4/Suspicious_sand_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_0.md
# 已读取 273 个文件。当前文件编号：273，路径：/content/drive/MyDrive/crawler_data/4/Swamp_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_1.md
# 已读取 274 个文件。当前文件编号：274，路径：/content/drive/MyDrive/crawler_data/4/Swamp_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_Hills_0.md
# 已读取 275 个文件。当前文件编号：275，路径：/content/drive/MyDrive/crawler_data/4/Swamp_Hills_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_Hills_1.md
# 已读取 276 个文件。当前文件编号：276，路径：/content/drive/MyDrive/crawler_data/4/Swamp_Hills_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_Hills_10.md
# 已读取 277 个文件。当前文件编号：277，路径：/content/drive/MyDrive/crawler_data/4/Swamp_Hills_10.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_Hills_11.md
# 已读取 278 个文件。当前文件编号：278，路径：/content/drive/MyDrive/crawler_data/4/Swamp_Hills_11.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_Hills_12.md
# 已读取 279 个文件。当前文件编号：279，路径：/content/drive/MyDrive/crawler_data/4/Swamp_Hills_12.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_Hills_13.md
# 已读取 280 个文件。当前文件编号：280，路径：/content/drive/MyDrive/crawler_data/4/Swamp_Hills_13.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_Hills_14.md
# 已读取 281 个文件。当前文件编号：281，路径：/content/drive/MyDrive/crawler_data/4/Swamp_Hills_14.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_Hills_15.md
# 已读取 282 个文件。当前文件编号：282，路径：/content/drive/MyDrive/crawler_data/4/Swamp_Hills_15.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_Hills_16.md
# 已读取 283 个文件。当前文件编号：283，路径：/content/drive/MyDrive/crawler_data/4/Swamp_Hills_16.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_Hills_17.md
# 已读取 284 个文件。当前文件编号：284，路径：/content/drive/MyDrive/crawler_data/4/Swamp_Hills_17.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_Hills_18.md
# 已读取 285 个文件。当前文件编号：285，路径：/content/drive/MyDrive/crawler_data/4/Swamp_Hills_18.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_Hills_2.md
# 已读取 286 个文件。当前文件编号：286，路径：/content/drive/MyDrive/crawler_data/4/Swamp_Hills_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_Hills_3.md
# 已读取 287 个文件。当前文件编号：287，路径：/content/drive/MyDrive/crawler_data/4/Swamp_Hills_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_Hills_4.md
# 已读取 288 个文件。当前文件编号：288，路径：/content/drive/MyDrive/crawler_data/4/Swamp_Hills_4.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_Hills_5.md
# 已读取 289 个文件。当前文件编号：289，路径：/content/drive/MyDrive/crawler_data/4/Swamp_Hills_5.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_Hills_6.md
# 已读取 290 个文件。当前文件编号：290，路径：/content/drive/MyDrive/crawler_data/4/Swamp_Hills_6.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_Hills_7.md
# 已读取 291 个文件。当前文件编号：291，路径：/content/drive/MyDrive/crawler_data/4/Swamp_Hills_7.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_Hills_8.md
# 已读取 292 个文件。当前文件编号：292，路径：/content/drive/MyDrive/crawler_data/4/Swamp_Hills_8.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_Hills_9.md
# 已读取 293 个文件。当前文件编号：293，路径：/content/drive/MyDrive/crawler_data/4/Swamp_Hills_9.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swamp_hut_0.md
# 已读取 294 个文件。当前文件编号：294，路径：/content/drive/MyDrive/crawler_data/4/Swamp_hut_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sweet_Berry_farming_0.md
# 已读取 295 个文件。当前文件编号：295，路径：/content/drive/MyDrive/crawler_data/4/Sweet_Berry_farming_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sweet_berry_0.md
# 已读取 296 个文件。当前文件编号：296，路径：/content/drive/MyDrive/crawler_data/4/Sweet_berry_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Sweet_berry_1.md
# 已读取 297 个文件。当前文件编号：297，路径：/content/drive/MyDrive/crawler_data/4/Sweet_berry_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Swimming_0.md
# 已读取 298 个文件。当前文件编号：298，路径：/content/drive/MyDrive/crawler_data/4/Swimming_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/TNT_0.md
# 已读取 299 个文件。当前文件编号：299，路径：/content/drive/MyDrive/crawler_data/4/TNT_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/TNT_1.md
# 已保存 3 个数据集。
# 已读取 300 个文件。当前文件编号：300，路径：/content/drive/MyDrive/crawler_data/4/TNT_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/TNT_cannons_0.md
# 已读取 301 个文件。当前文件编号：301，路径：/content/drive/MyDrive/crawler_data/4/TNT_cannons_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/TNT_cannons_1.md
# 已读取 302 个文件。当前文件编号：302，路径：/content/drive/MyDrive/crawler_data/4/TNT_cannons_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/TNT_cannons_2.md
# 已读取 303 个文件。当前文件编号：303，路径：/content/drive/MyDrive/crawler_data/4/TNT_cannons_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/TNT_cannons_3.md
# 已读取 304 个文件。当前文件编号：304，路径：/content/drive/MyDrive/crawler_data/4/TNT_cannons_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/TNT_cannons_4.md
# 已读取 305 个文件。当前文件编号：305，路径：/content/drive/MyDrive/crawler_data/4/TNT_cannons_4.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/TNT_cannons_5.md
# 已读取 306 个文件。当前文件编号：306，路径：/content/drive/MyDrive/crawler_data/4/TNT_cannons_5.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Taiga_0.md
# 已读取 307 个文件。当前文件编号：307，路径：/content/drive/MyDrive/crawler_data/4/Taiga_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Taiga_1.md
# 已读取 308 个文件。当前文件编号：308，路径：/content/drive/MyDrive/crawler_data/4/Taiga_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Taiga_Hills_0.md
# 已读取 309 个文件。当前文件编号：309，路径：/content/drive/MyDrive/crawler_data/4/Taiga_Hills_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Taiga_Hills_1.md
# 已读取 310 个文件。当前文件编号：310，路径：/content/drive/MyDrive/crawler_data/4/Taiga_Hills_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Taiga_Hills_10.md
# 已读取 311 个文件。当前文件编号：311，路径：/content/drive/MyDrive/crawler_data/4/Taiga_Hills_10.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Taiga_Hills_11.md
# 已读取 312 个文件。当前文件编号：312，路径：/content/drive/MyDrive/crawler_data/4/Taiga_Hills_11.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Taiga_Hills_12.md
# 已读取 313 个文件。当前文件编号：313，路径：/content/drive/MyDrive/crawler_data/4/Taiga_Hills_12.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Taiga_Hills_13.md
# 已读取 314 个文件。当前文件编号：314，路径：/content/drive/MyDrive/crawler_data/4/Taiga_Hills_13.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Taiga_Hills_14.md
# 已读取 315 个文件。当前文件编号：315，路径：/content/drive/MyDrive/crawler_data/4/Taiga_Hills_14.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Taiga_Hills_15.md
# 已读取 316 个文件。当前文件编号：316，路径：/content/drive/MyDrive/crawler_data/4/Taiga_Hills_15.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Taiga_Hills_16.md
# 已读取 317 个文件。当前文件编号：317，路径：/content/drive/MyDrive/crawler_data/4/Taiga_Hills_16.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Taiga_Hills_17.md
# 已读取 318 个文件。当前文件编号：318，路径：/content/drive/MyDrive/crawler_data/4/Taiga_Hills_17.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Taiga_Hills_18.md
# 已读取 319 个文件。当前文件编号：319，路径：/content/drive/MyDrive/crawler_data/4/Taiga_Hills_18.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Taiga_Hills_2.md
# 已读取 320 个文件。当前文件编号：320，路径：/content/drive/MyDrive/crawler_data/4/Taiga_Hills_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Taiga_Hills_3.md
# 已读取 321 个文件。当前文件编号：321，路径：/content/drive/MyDrive/crawler_data/4/Taiga_Hills_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Taiga_Hills_4.md
# 已读取 322 个文件。当前文件编号：322，路径：/content/drive/MyDrive/crawler_data/4/Taiga_Hills_4.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Taiga_Hills_5.md
# ...
# An error in /content/drive/MyDrive/crawler_data/4/Wolf_and_fox_farming_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wolves_0.md
# 已读取 691 个文件。当前文件编号：691，路径：/content/drive/MyDrive/crawler_data/4/Wolves_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wolves_1.md
# 已读取 692 个文件。当前文件编号：692，路径：/content/drive/MyDrive/crawler_data/4/Wolves_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wolves_2.md
# 已读取 693 个文件。当前文件编号：693，路径：/content/drive/MyDrive/crawler_data/4/Wolves_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Badlands_0.md
# 已读取 694 个文件。当前文件编号：694，路径：/content/drive/MyDrive/crawler_data/4/Wooded_Badlands_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Badlands_1.md
# 已读取 695 个文件。当前文件编号：695，路径：/content/drive/MyDrive/crawler_data/4/Wooded_Badlands_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Badlands_2.md
# 已读取 696 个文件。当前文件编号：696，路径：/content/drive/MyDrive/crawler_data/4/Wooded_Badlands_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Hills_0.md
# 已读取 697 个文件。当前文件编号：697，路径：/content/drive/MyDrive/crawler_data/4/Wooded_Hills_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Hills_1.md
# 已读取 698 个文件。当前文件编号：698，路径：/content/drive/MyDrive/crawler_data/4/Wooded_Hills_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Hills_10.md
# Error processing file due to: Error code: 403 - {'error': {'message': 'user quota is not enough (request id: 20240423125115678410167lY2W1O7u) (request id: 2024042312473767085968262325425) (request id: 2024042312473764691126738220879) (request id: 2024042312473762171643466342281) (request id: 2024042312473759792218891196930) (request id: 2024042312473757073618090846051)', 'type': 'new_api_error', 'param': '', 'code': 'insufficient_user_quota'}}
# An error in /content/drive/MyDrive/crawler_data/4/Wooded_Hills_10.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Hills_11.md
# Error processing file due to: Error code: 403 - {'error': {'message': 'user quota is not enough (request id: 20240423125117494608330dPvDPCQh) (request id: 2024042312473948822126746491812)', 'type': 'new_api_error', 'param': '', 'code': 'insufficient_user_quota'}}
# An error in /content/drive/MyDrive/crawler_data/4/Wooded_Hills_11.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Hills_12.md
# 已读取 701 个文件。当前文件编号：701，路径：/content/drive/MyDrive/crawler_data/4/Wooded_Hills_12.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Hills_13.md
# Error processing file due to: Error code: 403 - {'error': {'message': 'user quota is not enough (request id: 20240423125215398560608ZunvRCoO) (request id: 2024042312483736417082546201647) (request id: 2024042312483734203389851017641) (request id: 2024042312483731181829732885912)', 'type': 'new_api_error', 'param': '', 'code': 'insufficient_user_quota'}}
# An error in /content/drive/MyDrive/crawler_data/4/Wooded_Hills_13.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Hills_14.md
# 已读取 703 个文件。当前文件编号：703，路径：/content/drive/MyDrive/crawler_data/4/Wooded_Hills_14.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Hills_15.md
# 已读取 704 个文件。当前文件编号：704，路径：/content/drive/MyDrive/crawler_data/4/Wooded_Hills_15.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Hills_16.md
# 已读取 705 个文件。当前文件编号：705，路径：/content/drive/MyDrive/crawler_data/4/Wooded_Hills_16.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Hills_17.md
# 已读取 706 个文件。当前文件编号：706，路径：/content/drive/MyDrive/crawler_data/4/Wooded_Hills_17.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Hills_18.md
# 已读取 707 个文件。当前文件编号：707，路径：/content/drive/MyDrive/crawler_data/4/Wooded_Hills_18.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Hills_2.md
# 已读取 708 个文件。当前文件编号：708，路径：/content/drive/MyDrive/crawler_data/4/Wooded_Hills_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Hills_3.md
# Error processing file due to: Error code: 403 - {'error': {'message': 'user quota is not enough (request id: 20240423125834385869087zNZx3grc) (request id: 2024042312545636984245876460237)', 'type': 'new_api_error', 'param': '', 'code': 'insufficient_user_quota'}}
# An error in /content/drive/MyDrive/crawler_data/4/Wooded_Hills_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Hills_4.md
# Error processing file due to: Error code: 403 - {'error': {'message': 'user quota is not enough (request id: 20240423125836168014239Qitp8xC5) (request id: 2024042312545815358573875297690)', 'type': 'new_api_error', 'param': '', 'code': 'insufficient_user_quota'}}
# An error in /content/drive/MyDrive/crawler_data/4/Wooded_Hills_4.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Hills_5.md
# Error processing file due to: Error code: 403 - {'error': {'message': 'user quota is not enough (request id: 20240423125838903176998uz5HugS) (request id: 202404231255006120723291258721)', 'type': 'new_api_error', 'param': '', 'code': 'insufficient_user_quota'}}
# An error in /content/drive/MyDrive/crawler_data/4/Wooded_Hills_5.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Hills_6.md
# 已读取 712 个文件。当前文件编号：712，路径：/content/drive/MyDrive/crawler_data/4/Wooded_Hills_6.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Hills_7.md
# 已读取 713 个文件。当前文件编号：713，路径：/content/drive/MyDrive/crawler_data/4/Wooded_Hills_7.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Hills_8.md
# 已读取 714 个文件。当前文件编号：714，路径：/content/drive/MyDrive/crawler_data/4/Wooded_Hills_8.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wooded_Hills_9.md
# 已读取 715 个文件。当前文件编号：715，路径：/content/drive/MyDrive/crawler_data/4/Wooded_Hills_9.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Woodland_mansion_0.md
# Error processing file due to: Error code: 403 - {'error': {'message': 'user quota is not enough (request id: 2024042313023124278381aJt9nqOR) (request id: 2024042312585273668689203823779)', 'type': 'new_api_error', 'param': '', 'code': 'insufficient_user_quota'}}
# An error in /content/drive/MyDrive/crawler_data/4/Woodland_mansion_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Woodland_mansion_1.md
# Error processing file due to: Error code: 403 - {'error': {'message': 'user quota is not enough (request id: 20240423130232957028326aLBuMAO9) (request id: 2024042312585492999333600160566) (request id: 2024042312585489633231149044622) (request id: 2024042312585486223785312592764) (request id: 2024042312585482455752899701896)', 'type': 'new_api_error', 'param': '', 'code': 'insufficient_user_quota'}}
# An error in /content/drive/MyDrive/crawler_data/4/Woodland_mansion_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Woodland_mansion_2.md
# 已读取 718 个文件。当前文件编号：718，路径：/content/drive/MyDrive/crawler_data/4/Woodland_mansion_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wool_0.md
# 已读取 719 个文件。当前文件编号：719，路径：/content/drive/MyDrive/crawler_data/4/Wool_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wool_1.md
# 已读取 720 个文件。当前文件编号：720，路径：/content/drive/MyDrive/crawler_data/4/Wool_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Wool_farming_0.md
# 已读取 721 个文件。当前文件编号：721，路径：/content/drive/MyDrive/crawler_data/4/Wool_farming_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/World_0.md
# 已读取 722 个文件。当前文件编号：722，路径：/content/drive/MyDrive/crawler_data/4/World_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/World_Options_0.md
# 已读取 723 个文件。当前文件编号：723，路径：/content/drive/MyDrive/crawler_data/4/World_Options_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/World_border_0.md
# 已读取 724 个文件。当前文件编号：724，路径：/content/drive/MyDrive/crawler_data/4/World_border_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/World_border_1.md
# 已读取 725 个文件。当前文件编号：725，路径：/content/drive/MyDrive/crawler_data/4/World_border_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/World_boundary_0.md
# 已读取 726 个文件。当前文件编号：726，路径：/content/drive/MyDrive/crawler_data/4/World_boundary_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/World_boundary_1.md
# 已读取 727 个文件。当前文件编号：727，路径：/content/drive/MyDrive/crawler_data/4/World_boundary_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/World_generation_0.md
# Error processing file due to: Error code: 403 - {'error': {'message': 'user quota is not enough (request id: 20240423131215681970874eyGUTew6) (request id: 2024042313083764597223964745429)', 'type': 'new_api_error', 'param': '', 'code': 'insufficient_user_quota'}}
# An error in /content/drive/MyDrive/crawler_data/4/World_generation_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/World_generation_1.md
# 已读取 729 个文件。当前文件编号：729，路径：/content/drive/MyDrive/crawler_data/4/World_generation_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/World_generation_2.md
# Error processing file due to: Error code: 403 - {'error': {'message': 'user quota is not enough (request id: 20240423131310867124807zbsgop3I) (request id: 2024042313093283224318475397942) (request id: 2024042313093259258893550405029)', 'type': 'new_api_error', 'param': '', 'code': 'insufficient_user_quota'}}
# An error in /content/drive/MyDrive/crawler_data/4/World_generation_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/World_generation_3.md
# Error processing file due to: Error code: 403 - {'error': {'message': 'user quota is not enough (request id: 20240423131312839593167kIawtQv6) (request id: 2024042313093480729842870014974) (request id: 2024042313093477903542011229982)', 'type': 'new_api_error', 'param': '', 'code': 'insufficient_user_quota'}}
# An error in /content/drive/MyDrive/crawler_data/4/World_generation_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/World_generation_4.md
# 已读取 732 个文件。当前文件编号：732，路径：/content/drive/MyDrive/crawler_data/4/World_generation_4.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/World_size_0.md
# 已读取 733 个文件。当前文件编号：733，路径：/content/drive/MyDrive/crawler_data/4/World_size_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/World_type_0.md
# 已读取 734 个文件。当前文件编号：734，路径：/content/drive/MyDrive/crawler_data/4/World_type_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/X-ray_glitches_0.md
# 已读取 735 个文件。当前文件编号：735，路径：/content/drive/MyDrive/crawler_data/4/X-ray_glitches_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Your_first_10_minutes_0.md
# 已读取 736 个文件。当前文件编号：736，路径：/content/drive/MyDrive/crawler_data/4/Your_first_10_minutes_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Your_first_10_minutes_1.md
# 已读取 737 个文件。当前文件编号：737，路径：/content/drive/MyDrive/crawler_data/4/Your_first_10_minutes_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Your_first_10_minutes_2.md
# 已读取 738 个文件。当前文件编号：738，路径：/content/drive/MyDrive/crawler_data/4/Your_first_10_minutes_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Your_first_10_minutes_3.md
# 已读取 739 个文件。当前文件编号：739，路径：/content/drive/MyDrive/crawler_data/4/Your_first_10_minutes_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zero-ticking_0.md
# 已读取 740 个文件。当前文件编号：740，路径：/content/drive/MyDrive/crawler_data/4/Zero-ticking_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zero-ticking_1.md
# Error processing file due to: Error code: 403 - {'error': {'message': 'user quota is not enough (request id: 20240423132129885491707CRQVL47g) (request id: 2024042313175183940948825583541) (request id: 2024042313175179676010110126365)', 'type': 'new_api_error', 'param': '', 'code': 'insufficient_user_quota'}}
# An error in /content/drive/MyDrive/crawler_data/4/Zero-ticking_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombie_0.md
# 已读取 742 个文件。当前文件编号：742，路径：/content/drive/MyDrive/crawler_data/4/Zombie_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombie_1.md
# 已读取 743 个文件。当前文件编号：743，路径：/content/drive/MyDrive/crawler_data/4/Zombie_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombie_2.md
# 已读取 744 个文件。当前文件编号：744，路径：/content/drive/MyDrive/crawler_data/4/Zombie_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombie_3.md
# 已读取 745 个文件。当前文件编号：745，路径：/content/drive/MyDrive/crawler_data/4/Zombie_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombie_Pigmen_0.md
# 已读取 746 个文件。当前文件编号：746，路径：/content/drive/MyDrive/crawler_data/4/Zombie_Pigmen_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombie_Pigmen_1.md
# 已读取 747 个文件。当前文件编号：747，路径：/content/drive/MyDrive/crawler_data/4/Zombie_Pigmen_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombie_farming_0.md
# 已读取 748 个文件。当前文件编号：748，路径：/content/drive/MyDrive/crawler_data/4/Zombie_farming_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombie_farming_1.md
# 已读取 749 个文件。当前文件编号：749，路径：/content/drive/MyDrive/crawler_data/4/Zombie_farming_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombie_farming_2.md
# 已读取 750 个文件。当前文件编号：750，路径：/content/drive/MyDrive/crawler_data/4/Zombie_farming_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombie_farming_3.md
# 已读取 751 个文件。当前文件编号：751，路径：/content/drive/MyDrive/crawler_data/4/Zombie_farming_3.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombie_farming_4.md
# 已读取 752 个文件。当前文件编号：752，路径：/content/drive/MyDrive/crawler_data/4/Zombie_farming_4.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombie_farming_5.md
# Error processing file due to: Error code: 403 - {'error': {'message': 'user quota is not enough (request id: 20240423133226225270175zPKA3yau) (request id: 2024042313284816699046263340111)', 'type': 'new_api_error', 'param': '', 'code': 'insufficient_user_quota'}}
# An error in /content/drive/MyDrive/crawler_data/4/Zombie_farming_5.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombie_siege_0.md
# 已读取 754 个文件。当前文件编号：754，路径：/content/drive/MyDrive/crawler_data/4/Zombie_siege_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombie_siege_defense_0.md
# Error processing file due to: Error code: 403 - {'error': {'message': 'user quota is not enough (request id: 202404231333055525036182NH9nHyW) (request id: 2024042313292729064392892775340)', 'type': 'new_api_error', 'param': '', 'code': 'insufficient_user_quota'}}
# An error in /content/drive/MyDrive/crawler_data/4/Zombie_siege_defense_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombie_villager_0.md
# 已读取 756 个文件。当前文件编号：756，路径：/content/drive/MyDrive/crawler_data/4/Zombie_villager_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombie_villager_1.md
# 已读取 757 个文件。当前文件编号：757，路径：/content/drive/MyDrive/crawler_data/4/Zombie_villager_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombie_villager_2.md
# 已读取 758 个文件。当前文件编号：758，路径：/content/drive/MyDrive/crawler_data/4/Zombie_villager_2.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombie_villager_farming_0.md
# Error processing file due to: Error code: 403 - {'error': {'message': 'user quota is not enough (request id: 20240423133527589334152eoNVO4y9) (request id: 2024042313314934271618757622285)', 'type': 'new_api_error', 'param': '', 'code': 'insufficient_user_quota'}}
# An error in /content/drive/MyDrive/crawler_data/4/Zombie_villager_farming_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombie_villager_sorting_0.md
# Error processing file due to: Error code: 403 - {'error': {'message': 'user quota is not enough (request id: 20240423133530452280665XptBUOiU) (request id: 2024042313315220834326320891469) (request id: 2024042313315217102586946137466) (request id: 2024042313315213677311439596077) (request id: 2024042313315210599928563019812) (request id: 202404231331527259208665127778)', 'type': 'new_api_error', 'param': '', 'code': 'insufficient_user_quota'}}
# An error in /content/drive/MyDrive/crawler_data/4/Zombie_villager_sorting_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombified_Piglin_0.md
# 已读取 761 个文件。当前文件编号：761，路径：/content/drive/MyDrive/crawler_data/4/Zombified_Piglin_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombified_Piglin_1.md
# 已读取 762 个文件。当前文件编号：762，路径：/content/drive/MyDrive/crawler_data/4/Zombified_Piglin_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombified_Piglin_farming_0.md
# 已读取 763 个文件。当前文件编号：763，路径：/content/drive/MyDrive/crawler_data/4/Zombified_Piglin_farming_0.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombified_Piglin_farming_1.md
# 已读取 764 个文件。当前文件编号：764，路径：/content/drive/MyDrive/crawler_data/4/Zombified_Piglin_farming_1.md
# 正在读取: /content/drive/MyDrive/crawler_data/4/Zombified_Piglin_farming_2.md
# 已读取 765 个文件。当前文件编号：765，路径：/content/drive/MyDrive/crawler_data/4/Zombified_Piglin_farming_2.md
